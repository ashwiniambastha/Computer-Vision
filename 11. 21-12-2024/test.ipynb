# %%
import torch
import torch.nn as nn

# %%
class LinearR(nn.Module):
    def __init__(self):
        super(LinearR,self).__init__()
        self.linear=nn.Linear(in_features=1,out_features=1)
    
    def forward(self,x):
        out=self.linear(x)
        return out

# %%
x=torch.rand(size=(4,1))
y=torch.rand(size=(4,1))

# %%
x
# Out:
# tensor([[0.4740],
#         [0.3048],
#         [0.1721],
#         [0.7526]])

# %%
p=x.squeeze()
print(p)
# Out:
# tensor([0.4740, 0.3048, 0.1721, 0.7526])

# %%
p.ndim
# Out:
# 1

# %%
p.shape
# Out:
# torch.Size([4])

# %%
model=LinearR()

# %%
cre=nn.MSELoss()
optimizer=torch.optim.SGD(model.parameters(),lr=0.01)

# %%
e=1000
for epoch in range(e):
    
    y_pred=model(x)
    loss=cre(y,y_pred)
    
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    
    if epoch%100==0:
        print(f"For Epoch:{epoch} , the loss is {loss}\n")
# Out:
# For Epoch:0 , the loss is 0.28065186738967896
#
# For Epoch:100 , the loss is 0.028598934412002563
#
# For Epoch:200 , the loss is 0.026516053825616837
#
# For Epoch:300 , the loss is 0.02646927535533905
#
# For Epoch:400 , the loss is 0.026443418115377426
#
# For Epoch:500 , the loss is 0.026421457529067993
#
# For Epoch:600 , the loss is 0.026402708142995834
#
# For Epoch:700 , the loss is 0.026386717334389687
#
# For Epoch:800 , the loss is 0.02637304924428463
#
# For Epoch:900 , the loss is 0.026361390948295593
